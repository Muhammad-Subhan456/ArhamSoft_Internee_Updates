# %%
import numpy as np

# %%
arr = np.array([
    [0.2, 0.8, 0.4],
    [0.9, 0.1, 0.7],
    [0.3, 0.6, 0.2]
])

# %%
arr[arr > 0.5]
# Out:
# array([0.8, 0.9, 0.7, 0.6])

# %%
data = np.array([
    [10, 20, 30, 40],
    [20, 30, 40, 50],
    [30, 40, 50, 60]
])

# %%
data.shape
# Out:
# (3, 4)

# %%
data.mean(axis=0)
# Out:
# array([20., 30., 40., 50.])

# %%
data.mean(axis=1)
# Out:
# array([25., 35., 45.])

# %%
data.mean(axis=0)
# Out:
# array([20., 30., 40., 50.])

# %%
data.mean(axis=1)
# Out:
# array([25., 35., 45.])
